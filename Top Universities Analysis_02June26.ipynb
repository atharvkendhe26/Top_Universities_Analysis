# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('../DataSet/Top_University.csv')

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df = df.rename(columns = {'world_rank' : 'worldrank','national_rank' : 'nationalrank','quality_of_education':'qualityofeducation','alumni_employment':'alumniemployment',
                          'quality_of_faculty':'qualityoffaculty','broad_impact':'broadimpact'	})

# %%
df
# Out:
#       worldrank                            institution         country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5     California Institute of Technology             USA
# ...         ...                                    ...             ...
# 2195        996              University of the Algarve        Portugal
# 2196        997                  Alexandria University           Egypt
# 2197        998            Federal University of Ceará          Brazil
# 2198        999                 University of A Coruña           Spain
# 2199       1000        China Pharmaceutical University           China
#
#       nationalrank  qualityofeducation  alumniemployment  qualityoffaculty  \
# ...

# %%
df.dtypes
# Out:
# worldrank               int64
# institution            object
# country                object
# nationalrank            int64
# qualityofeducation      int64
# alumniemployment        int64
# qualityoffaculty        int64
# publications            int64
# influence               int64
# citations               int64
# broadimpact           float64
# patents                 int64
# score                 float64
# year                    int64
# dtype: object

# %%
df.head(10)
# Out:
#    worldrank                            institution         country  \
# 0          1                     Harvard University             USA
# 1          2  Massachusetts Institute of Technology             USA
# 2          3                    Stanford University             USA
# 3          4                University of Cambridge  United Kingdom
# 4          5     California Institute of Technology             USA
# 5          6                   Princeton University             USA
# 6          7                   University of Oxford  United Kingdom
# 7          8                        Yale University             USA
# 8          9                    Columbia University             USA
# 9         10     University of California, Berkeley             USA
#
#    nationalrank  qualityofeducation  alumniemployment  qualityoffaculty  \
# 0             1                   7                 9                 1
# 1             2                   9                17                 3
# ...

# %%
df.isnull().sum()
# Out:
# worldrank               0
# institution             0
# country                 0
# nationalrank            0
# qualityofeducation      0
# alumniemployment        0
# qualityoffaculty        0
# publications            0
# influence               0
# citations               0
# broadimpact           200
# patents                 0
# score                   0
# year                    0
# dtype: int64

# %%
df.broadimpact =df.broadimpact.fillna(0)

# %% [markdown]
# # 2. EDA

# %%
df.describe()
# Out:
#          worldrank  nationalrank  qualityofeducation  alumniemployment  \
# count  2200.000000   2200.000000         2200.000000       2200.000000
# mean    459.590909     40.278182          275.100455        357.116818
# std     304.320363     51.740870          121.935100        186.779252
# min       1.000000      1.000000            1.000000          1.000000
# 25%     175.750000      6.000000          175.750000        175.750000
# 50%     450.500000     21.000000          355.000000        450.500000
# 75%     725.250000     49.000000          367.000000        478.000000
# max    1000.000000    229.000000          367.000000        567.000000
#
#        qualityoffaculty  publications    influence    citations  broadimpact  \
# count       2200.000000   2200.000000  2200.000000  2200.000000  2200.000000
# mean         178.888182    459.908636   459.797727   413.417273   451.545000
# std           64.050885    303.760352   303.331822   264.366549   308.600387
# ...

# %%
    df.groupby('institution')['country'].sum()
# Out:
# institution
# AGH University of Science and Technology                    PolandPoland
# Aalborg University                                        DenmarkDenmark
# Aalto University                                          FinlandFinland
# Aarhus University                                         DenmarkDenmark
# Aberystwyth University                      United KingdomUnited Kingdom
#                                                         ...
# École centrale de Lyon                                            France
# École normale supérieure - Paris                FranceFranceFranceFrance
# École normale supérieure de Cachan                                France
# École normale supérieure de Lyon                            FranceFrance
# Örebro University                                           SwedenSweden
# Name: country, Length: 1024, dtype: object

# %%
df.groupby('country')['score'].mean()
# Out:
# country
# Argentina               44.672857
# Australia               45.825517
# Austria                 45.139583
# Belgium                 47.011000
# Brazil                  44.781111
# Bulgaria                44.335000
# Canada                  47.359306
# Chile                   44.767500
# China                   44.992575
# Colombia                44.432500
# Croatia                 44.770000
# Cyprus                  44.210000
# Czech Republic          44.761000
# Denmark                 47.774167
# Egypt                   44.230000
# Estonia                 44.810000
# Finland                 45.531500
# France                  46.367339
# Germany                 46.413130
# Greece                  44.854286
# Hong Kong               46.295000
# Hungary                 44.603333
# Iceland                 44.980000
# India                   44.713226
# Iran                    44.270000
# Ireland                 45.235000
# Israel                  52.654091
# ...

# %%
df.groupby('country')['score'].sum()
# Out:
# country
# Argentina                 312.71
# Australia                2657.88
# Austria                  1083.35
# Belgium                   940.22
# Brazil                   1612.12
# Bulgaria                   88.67
# Canada                   3409.87
# Chile                     358.14
# China                    7513.76
# Colombia                  177.73
# Croatia                    89.54
# Cyprus                     88.42
# Czech Republic            447.61
# Denmark                   573.29
# Egypt                     353.84
# Estonia                    89.62
# Finland                   910.63
# France                   5054.04
# Germany                  5337.51
# Greece                    627.96
# Hong Kong                 555.54
# Hungary                   535.24
# Iceland                    89.96
# India                    1386.11
# Iran                      708.32
# Ireland                   723.76
# Israel                   1158.39
# Italy                    4363.22
# ...

# %%
df.groupby('institution')['score'].mean()
# Out:
# institution
# AGH University of Science and Technology    44.485
# Aalborg University                          44.710
# Aalto University                            45.340
# Aarhus University                           49.910
# Aberystwyth University                      44.375
#                                              ...
# École centrale de Lyon                      44.150
# École normale supérieure - Paris            53.830
# École normale supérieure de Cachan          44.330
# École normale supérieure de Lyon            45.060
# Örebro University                           44.570
# Name: score, Length: 1024, dtype: float64

# %%
df.groupby('institution')['score'].sum()
# Out:
# institution
# AGH University of Science and Technology     88.97
# Aalborg University                           89.42
# Aalto University                             90.68
# Aarhus University                            99.82
# Aberystwyth University                       88.75
#                                              ...
# École centrale de Lyon                       44.15
# École normale supérieure - Paris            215.32
# École normale supérieure de Cachan           44.33
# École normale supérieure de Lyon             90.12
# Örebro University                            89.14
# Name: score, Length: 1024, dtype: float64

# %%
sb.histplot(df.score)
plt.show()

# %%
sb.boxplot(df.score)
plt.show()

# %% [markdown]
# # 3. Top Universities Analysis:

# %%
y = df[df.year == 2015]
y.sort_values('worldrank').head(10)
# Out:
#       worldrank                            institution         country  \
# 1200          1                     Harvard University             USA
# 1201          2                    Stanford University             USA
# 1202          3  Massachusetts Institute of Technology             USA
# 1203          4                University of Cambridge  United Kingdom
# 1204          5                   University of Oxford  United Kingdom
# 1205          6                    Columbia University             USA
# 1206          7     University of California, Berkeley             USA
# 1207          8                  University of Chicago             USA
# 1208          9                   Princeton University             USA
# 1209         10                     Cornell University             USA
#
#       nationalrank  qualityofeducation  alumniemployment  qualityoffaculty  \
# 1200             1                   1                 1                 1
# ...

# %%
df.groupby('institution')[['worldrank','nationalrank','score']].count().nsmallest(10,'worldrank')
# Out:
#                                          worldrank  nationalrank  score
# institution
# Babeș-Bolyai University                          1             1      1
# Beijing Jiaotong University                      1             1      1
# Chemnitz University of Technology                1             1      1
# China University of Geosciences (Wuhan)          1             1      1
# Gachon University                                1             1      1
# Guangxi University                               1             1      1
# Harbin Engineering University                    1             1      1
# Harbin Medical University                        1             1      1
# Hefei University of Technology                   1             1      1
# Henan Normal University                          1             1      1

# %% [markdown]
# # 4. Country Performanace

# %%
df.groupby('institution')[['worldrank']].value_counts().head(100)
# Out:
# institution                               worldrank
# AGH University of Science and Technology  653          1
#                                           782          1
# Aalborg University                        565          1
#                                           593          1
# Aalto University                          392          1
#                                                       ..
# Brigham Young University                  403          1
#                                           415          1
# Brock University                          861          1
#                                           884          1
# Brown University                          66           1
# Name: count, Length: 100, dtype: int64

# %%
print(df.institution.unique())
inst = input("Enter Institution Name : ")
i = df[df.institution == inst]

sb.countplot(x= i.institution )
plt.show()
# Out:
# ['Harvard University' 'Massachusetts Institute of Technology'
#  'Stanford University' ... 'Babeș-Bolyai University'
#  'Henan Normal University' 'Southwest Jiaotong University']
# Enter Institution Name :  Southwest Jiaotong University

# %%
df.groupby('country')['score'].mean()
# Out:
# country
# Argentina               44.672857
# Australia               45.825517
# Austria                 45.139583
# Belgium                 47.011000
# Brazil                  44.781111
# Bulgaria                44.335000
# Canada                  47.359306
# Chile                   44.767500
# China                   44.992575
# Colombia                44.432500
# Croatia                 44.770000
# Cyprus                  44.210000
# Czech Republic          44.761000
# Denmark                 47.774167
# Egypt                   44.230000
# Estonia                 44.810000
# Finland                 45.531500
# France                  46.367339
# Germany                 46.413130
# Greece                  44.854286
# Hong Kong               46.295000
# Hungary                 44.603333
# Iceland                 44.980000
# India                   44.713226
# Iran                    44.270000
# Ireland                 45.235000
# Israel                  52.654091
# ...

# %% [markdown]
# # 5. Factor Analysis

# %%
a = df.corr(numeric_only= True)
a
# Out:
#                     worldrank  nationalrank  qualityofeducation  \
# worldrank            1.000000      0.238553            0.676166
# nationalrank         0.238553      1.000000            0.211975
# qualityofeducation   0.676166      0.211975            1.000000
# alumniemployment     0.668529      0.135342            0.606421
# qualityoffaculty     0.663864      0.222833            0.786181
# publications         0.923037      0.326857            0.624657
# influence            0.895871      0.161086            0.645641
# citations            0.856573      0.186797            0.630455
# broadimpact          0.953006      0.214437            0.637312
# patents              0.698214      0.159440            0.528120
# score               -0.549098     -0.199756           -0.600541
# year                 0.320844      0.102951            0.427732
#
#                     alumniemployment  qualityoffaculty  publications  \
# ...

# %%
plt.scatter(df.citations , df.score)
plt.show()

# %%
plt.scatter(df.qualityofeducation , df.alumniemployment , df.qualityoffaculty)
plt.show()

# %% [markdown]
# # 6. Trend Analysis

# %%
df.groupby('institution')['year'].mean()
# Out:
# institution
# AGH University of Science and Technology    2014.5
# Aalborg University                          2014.5
# Aalto University                            2014.5
# Aarhus University                           2014.5
# Aberystwyth University                      2014.5
#                                              ...
# École centrale de Lyon                      2015.0
# École normale supérieure - Paris            2013.5
# École normale supérieure de Cachan          2015.0
# École normale supérieure de Lyon            2014.5
# Örebro University                           2014.5
# Name: year, Length: 1024, dtype: float64

# %%
df.score = df.score.fillna(0)
df
# Out:
#       worldrank                            institution         country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5     California Institute of Technology             USA
# ...         ...                                    ...             ...
# 2195        996              University of the Algarve        Portugal
# 2196        997                  Alexandria University           Egypt
# 2197        998            Federal University of Ceará          Brazil
# 2198        999                 University of A Coruña           Spain
# 2199       1000        China Pharmaceutical University           China
#
#       nationalrank  qualityofeducation  alumniemployment  qualityoffaculty  \
# ...

# %%
pd.pivot_table(df, index='institution' , columns = 'year' , values ='score' , aggfunc='sum' , margins = True)
# Out:
# year                                         2012     2013      2014  \
# institution
# AGH University of Science and Technology      NaN      NaN     44.71
# Aalborg University                            NaN      NaN     44.83
# Aalto University                              NaN      NaN     45.58
# Aarhus University                             NaN      NaN     50.17
# Aberystwyth University                        NaN      NaN     44.53
# ...                                           ...      ...       ...
# École normale supérieure - Paris            49.10    47.70     59.72
# École normale supérieure de Cachan            NaN      NaN       NaN
# École normale supérieure de Lyon              NaN      NaN     45.25
# Örebro University                             NaN      NaN     44.70
# All                                       5494.09  5527.12  47271.41
#
# year                                          2015        All
# institution
# ...

# %%
sb.heatmap(a , annot= True)
plt.show()
